# %%
import os
directory = "please_add_directory"
os.chdir(directory)
csv_path = 'UrbanSound\\UrbanSound8K\\metadata\\UrbanSound8K.csv'

from Scripts import predictions as pred
# Out:
# C:\Users\giorg\miniconda3\envs\dl\Lib\site-packages\pyAudioAnalysis\..\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %% [markdown]
# # One sample Demo

# %% [markdown]
# This is a high level Demo of our model the only things you need to do are:
# * Provide file path : filename
#
# * Choose one model from the folder Models ang give the path to it
#
# * Clarify what type of model it is
#
#     - "NN" --- ---> Simple fully connected architecture
#     - "CNN" ------> Convolutional Neural Network architecture
#     - "YamNet" ---> Features Generated from Yamnet and transfered learned into UrbanSound8k Dataset (Only avaliable for UrbanSound8k Test Set)

# %%
sounds_to_test = ["UrbanSound\\Test\\7389-1-0-7.wav","UrbanSound\\Test\\74364-8-1-4.wav","UrbanSound\Test\\135528-6-5-0.wav","UrbanSound\\Test\\23218-5-0-0.wav","Test_Sounds\\roommate_dog.wav"]

models_to_test= [
                    ("Models\\Fully_Connected.h5", "NN"), 
                    ("Models\\UrbanSound_CNN.h5", "CNN"),
                    ("Models\\Transfer_Learning_Stride_final.h5", "CNN"),
                    ("Models\\YamNet.h5","YamNet")
                ]

# %%
sound = sounds_to_test[4]
model_number = 2

# %%
filename = sound
model_path = models_to_test[model_number][0]
model_type = models_to_test[model_number][1]

# %%
pred.One_Sample_Prediction(filename, model_path, model_type)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ############################################################################################
#
# File not found in the CSV
#
# ############################################################################################
# (128, 81)
# 1/1 [==============================] - 0s 108ms/step
# ############################################################################################
#
# The model believes this sound is dog_bark with  100.00% confidence,
#
# ############################################################################################

# %% [markdown]
# # Test Set Demo

# %% [markdown]
# This Command makes predictions in the whole test set of UrbanSound8k. The only thing which you need to provide is the model of your preference from Models Folder.

# %%
model = "Models\\Transfer_Learning_Stride_final.h5"
model_type = "CNN"
pred.Train_Set_Predictions(model, model_type)
# Out:
# 55/55 [==============================] - 1s 8ms/step
# Accuracy: 0.911697247706422
# F1 Score: 0.9118455218501875

# %%
from Scripts import Model_Training as mt

mt.model_load("Models\\YamNet.h5")
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_6 (Flatten)         (None, 1024)              0
#
#  dense_24 (Dense)            (None, 2048)              2099200
#
#  dropout_16 (Dropout)        (None, 2048)              0
#
#  dense_25 (Dense)            (None, 1024)              2098176
#
#  dropout_17 (Dropout)        (None, 1024)              0
#
#  dense_26 (Dense)            (None, 512)               524800
#
#  dropout_18 (Dropout)        (None, 512)               0
#
#  dense_27 (Dense)            (None, 512)               262656
#
#  dense_28 (Dense)            (None, 10)                5130
#
# ...
# Total params: 4,989,962
# Trainable params: 4,989,962
# Non-trainable params: 0
# _________________________________________________________________
# None
